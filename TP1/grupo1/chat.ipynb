# %% [markdown]
# **TP N°1**
#
# **Integrantes:**
#
# *  Aaron Ezequiel Busto
# *  Luis Alberto Giano
# *  Lucas Exequiel Cisneros
# *  Thomas Christian Mori Delponte

# %% [markdown]
# **1. Análisis Chatbot: Banco Nación **
#
# * Comenzando con un saludo y preguntando cómo ayudarte, te da una serie de opciones a elegir.
#
# * Al seleccionar alguna de las opciones (En este caso usamos de ejemplo “Canales”) Te da información al respecto (En este caso sobre los Cajeros Automáticos, Home Banking y BNA+).
#
# * Luego responde con más opciones (En este caso, preguntas frecuentes relacionadas al tema seleccionado).
#
# * Al seleccionar (En este caso, Home Banking) te da más información relacionada y detallada, además de ofrecerte links de acceso (En este caso, te explica que datos necesitas para ingresar, registrarse y operar en general, además de darte algunos links de ayuda adicional).
#
# * Luego de esto, te pregunta “¿Tenes más consultas”? Dejando abierta la posibilidad de que escribas. Si no entiende que le estas pasando de información en el mensaje, procede a darte una lista de opciones (Repitiendo el menú original).
#
# * La única forma de salir del chat es ignorándolo o bien cerrandolo (Que en realidad lo minimiza).-

# %% [markdown]
# ![Agregar un título (10).png](data:image/png;base64,...)

# %% [markdown]
# **Chat Bot - Punto Digital.**
#
# Este chat funciona correctamente y al finalizar la carga de datos gráfica los usuarios guardados. Se puede probar ejecutando el colab.

# %%
import matplotlib.pyplot as plt
# Inicializadores para las funciones


nombre_usuario_actual = ""
usuario_temporal = []
usuarios = {
    11111111: ["Marta Martinez", 40, "Mar Chiquita", "22311111", "MartitaM@gmail.com"],
    23222222: ["Juancito Juanes", 31, "Mar del Plata", "22322222", "JuanchiJ@hotmail.com"],
    24222222: ["Juancita Juan", 21, "Santa Clara del Mar", "2232222", "Juana@hotmail.com"],
    42821344: ["Thomas Mori", 23, "Santa Clara del Mar", "2233422", "thomasmori@odiseasoft.net"],
    262222222: ["Lucas Cisneros", 23, "Santa Clara del Mar", "2322222", "lucascisneros@odiseasoft.net"],
}

# Revisión y registro de usuarios
def revision():
    dni_temporal = int(input("Por favor, ingrese su DNI: "))
    if dni_temporal in usuarios:
        print(f"¡Hola, {usuarios[dni_temporal][0]}!")
        return usuarios[dni_temporal]
    else:
        nombre_temporal = input("Ud. no está registrad@. Por favor, ingrese su nombre: ")
        edad_temporal = input("Por favor, ingrese su edad: ")
        ciudad_temporal = input("Por favor, ingrese su ciudad: ")
        telefono_temporal = input("Por favor, ingrese su teléfono: ")
        email_temporal = input("Por favor, ingrese su correo electrónico: ")

        # Usar "Lorem Ipsum" si faltan datos
        edad_temporal = edad_temporal if edad_temporal else "No data"
        ciudad_temporal = ciudad_temporal if ciudad_temporal else "No data"
        telefono_temporal = telefono_temporal if telefono_temporal else "No data"
        email_temporal = email_temporal if email_temporal else "No data"

        # Registrar al usuario temporalmente
        usuarios[dni_temporal] = [nombre_temporal, edad_temporal, ciudad_temporal, telefono_temporal, email_temporal]
        print(f"Usuario {nombre_temporal} registrado exitosamente.")
        return usuarios[dni_temporal]

# Cursos
def curso_marketing():
    print("Elegiste Curso de Marketing Digital")
    print("► Día: Lunes 18 a 19 Hs | Viernes 19 a 20 Hs")
    print("► Tallerista: Thomas")
    volver_menu_principal()

def curso_eventos():
    print("Elegiste curso de Organización de Eventos")
    print("► Día: Jueves 18 a 19:30 Hs")
    print("► Tallerista: Oscar Alfredo Perez")
    volver_menu_principal()

def curso_oratoria():
    print("Elegiste curso de Oratoria")
    print("► Día: Martes 10 a 11:30 Hs")
    print("► Tallerista: Lara Ribero")
    volver_menu_principal()

def curso_audiovisual():
    print("Elegiste curso de Producción Audiovisual")
    print("► Día: Miércoles 18:30 a 20:30 Hs")
    print("► Tallerista: Agustín Escalada")
    volver_menu_principal()

def curso_fotografia():
    print("Elegiste curso de Fotografía")
    print("► Día: Martes 18 a 20 Hs")
    print("► Tallerista: Leonardo Barrios")
    volver_menu_principal()

def otras_capacitaciones():
    print("Elegiste otras Capacitaciones")
    print("Consultar en la oficina.")
    volver_menu_principal()

def volver_menu_principal():
    print("Volviendo al menú principal...")
    menu_principal()

# Menú de cursos
opciones = {
    '1': curso_marketing,
    '2': curso_eventos,
    '3': curso_audiovisual,
    '4': curso_oratoria,
    '5': curso_fotografia,
    '6': otras_capacitaciones,
    '7': volver_menu_principal,
}

# Opciones del menú principal
def opcion_a():
    print("Elegiste información sobre Costos, presencialidad y requisitos!")
    print("¿Qué costo tienen los cursos?")
    print("Los cursos son gratuitos e incluyen un certificado.")
    print("¿Cuál es la modalidad de cursada?")
    print("Las cursadas son presenciales en Av. del Arroyo 150, Santa Clara del Mar.")
    print("¿Volver a menu principal?")
    volver_menu_principal()

def opcion_b():
    print("Elegiste información Institucional!")
    print("Punto Digital es la iniciativa de inclusión digital y capacitación tecnológica más extensa de Argentina.")
    print("Los Puntos Digitales forman una red federal donde se ofrecen capacitaciones presenciales y virtuales, validación de identidad para Mi Argentina, soluciones tecnológicas, espacios de entretenimiento, conectividad wifi y uso de computadoras.")
    print("Este programa es llevado adelante por la Jefatura de Gabinete de Ministros y coordinado por la Secretaría de Cultura y Educación del Partido de Mar Chiquita.")
    print("En el Partido de Mar Chiquita contamos con dos Puntos Digitales, administrados por la Municipalidad de Mar Chiquita en conjunto con la Secretaría de Cultura y Educación. La sede de la región mediterránea está ubicada en Coronel Vidal (General Paz N°360) y la sede de la costa en Santa Clara del Mar (Av. del Arroyo 150).")
    volver_menu_principal()

def opcion_c():
    print("Elegiste Horarios de Atención y Contacto!")
    print("Estamos abiertos de lunes a viernes, de 10:00 a 14:00 y de 15:30 a 18:30.")
    volver_menu_principal()



def opcion_d():
    eleccion = "8"
    while eleccion not in opciones:
        print("""
        Elegiste Cursos Disponibles!
        1: Curso Marketing Digital
        2: Curso Organización de Eventos
        3: Curso Producción Audiovisual
        4: Curso Oratoria
        5: Curso Fotografía
        6: Otras Capacitaciones
        7: Volver al Menú Principal
        """)
        eleccion = input("¿Cuál es su elección (1 al 7)?: ")
        if eleccion in opciones:
            opciones[eleccion]()
        else:
            print("Elección no válida. Intente nuevamente.")


def opcion_e():
    print ("En Punto Digital también se ofrecen diversas capacitaciones impartidas por la Secretaría de Cultura y Educación, como el curso de Italiano básico y el curso de Marketing Digital para PUPAAs, así como por la Secretaría de Producción, que ofrece el curso de Manipulación de Alimentos.")
    volver_menu_principal()
    # otras_capacitaciones()

def opcion_f():
    print("Elegiste ¿Cómo me inscribo a un curso?")
    print("Las inscripciones son presenciales, exclusivas para residentes del Partido de Mar Chiquita y mayores de 18 años. Deberá completar un formulario de inscripción para el curso seleccionado de manera presencial en la oficina de Punto Digital (Av. del Arroyo 150), proporcionando su nombre completo, fecha de nacimiento, DNI, localidad de residencia, número de celular y correo electrónico.")
    volver_menu_principal()

# Diccionario de opciones del menú principal
menu = {
    "a": opcion_a,
    "b": opcion_b,
    "c": opcion_c,
    "d": opcion_d,
    "e": opcion_e,
    "f": opcion_f,
}

# Menú principal
def menu_principal():
    eleccion_menu = ""
    while eleccion_menu not in menu:
        print("""
        ¿Cómo podemos ayudarte?
        A: Información de Costos, Presencialidad y Requisitos
        B: Información Institucional
        C: Horarios de Atención y Contacto
        D: Cursos Disponibles
        E: Otras Capacitaciones
        F: Inscribirme
        """)
        eleccion_menu = input("Elija una opción (A B C D E F): ").lower()
        if eleccion_menu in menu:
            menu[eleccion_menu]()
        else:
            print("Opción no válida, intente nuevamente.")

# Ejecutar el chatbot
print("¡Bienvenid@ al sistema de inscripción!")
revision()



def preparar_datos_grafico(usuarios):

    ciudades = []
    edades = []
    for usuario in usuarios.values():
        ciudades.append(usuario[2])  # Índice 2 corresponde a la ciudad
        edades.append(int(usuario[1]))  # Índice 1 corresponde a la edad (convertimos a int)
    return ciudades, edades

# No utilizamos plt.plot porque faltan datos y se grafica mal. En cambio seleccionamos scatter
def crear_grafico(ciudades, edades):

    plt.scatter(ciudades, edades)
    plt.xlabel("Ciudad")
    plt.ylabel("Edad")
    plt.title("Distribución de Edades por Ciudad")
    plt.show()

ciudades, edades = preparar_datos_grafico(usuarios)
crear_grafico(ciudades, edades)
menu_principal()
# Out:
# ¡Bienvenid@ al sistema de inscripción!
# Por favor, ingrese su DNI: 42821344
# ¡Hola, Thomas Mori!
#         ¿Cómo podemos ayudarte?
#         A: Información de Costos, Presencialidad y Requisitos
#         B: Información Institucional
#         C: Horarios de Atención y Contacto
#         D: Cursos Disponibles
#         E: Otras Capacitaciones
#         F: Inscribirme
#
# Elija una opción (A B C D E F): b
# Elegiste información Institucional!
# Punto Digital es la iniciativa de inclusión digital y capacitación tecnológica más extensa de Argentina.
# Los Puntos Digitales forman una red federal donde se ofrecen capacitaciones presenciales y virtuales, validación de identidad para Mi Argentina, soluciones tecnológicas, espacios de entretenimiento, conectividad wifi y uso de computadoras.
# Este programa es llevado adelante por la Jefatura de Gabinete de Ministros y coordinado por la Secretaría de Cultura y Educación del Partido de Mar Chiquita.
# ...
